# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/alextfkd/TorchCode/blob/master/templates/09_causal_attention.ipynb)
#
# # 🔴 Hard: Causal Self-Attention
#
# Implement **causal (masked) self-attention** — the attention used in GPT-style decoders.
#
# Same as softmax attention, but each position can **only attend to itself and earlier positions** (no peeking at future tokens).
#
# $$\text{scores}_{ij} = \begin{cases} \frac{Q_i \cdot K_j}{\sqrt{d_k}} & \text{if } j \le i \\ -\infty & \text{if } j > i \end{cases}$$
#
#
# > 💡 **どこで使う**：GPT 系 autoregressive 生成に必須。未来 token を見ないよう三角行列でマスクする self-attention。
#
# <details>
# <summary>📖 もっと詳しく</summary>
#
# 上三角を `-inf` でマスクして softmax 後に 0 にする。生成時は前 token しか見られないので、teacher forcing による学習と推論の挙動が一致する。これが decoder-only Transformer の心臓部。
#
# </details>
#
# ### Signature
# ```python
# def causal_attention(Q, K, V):
#     # Q, K, V: (batch, seq, d) → output: (batch, seq, d_v)
# ```
#
# ### Rules
# - Do **NOT** use `F.scaled_dot_product_attention`
# - Position $i$ can only attend to positions $\le i$
# - You **may** use `torch.softmax`, `torch.bmm`, `torch.triu`

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q --force-reinstall --no-deps git+https://github.com/alextfkd/TorchCode.git')
except ImportError:
    pass

# %%
import torch
import math

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def causal_attention(Q, K, V):
    pass  # Replace this

# %%
# 🧪 Debug
torch.manual_seed(0)
Q = torch.randn(1, 4, 8)
K = torch.randn(1, 4, 8)
V = torch.randn(1, 4, 8)
out = causal_attention(Q, K, V)
print("Output shape:", out.shape)          # (1, 4, 8)
print("Pos 0 == V[0]?", torch.allclose(out[:, 0], V[:, 0], atol=1e-5))  # should be True

# %%
from torch_judge import check
check('causal_attention')

# %% [markdown]
# ---
#
# **詰まったら？** 解答を見る：
#
# [![Open Solution in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/alextfkd/TorchCode/blob/master/solutions/09_causal_attention_solution.ipynb) または [GitHub で開く](https://github.com/alextfkd/TorchCode/blob/master/solutions/09_causal_attention_solution.ipynb)
