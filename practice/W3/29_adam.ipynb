# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/alextfkd/TorchCode/blob/master/templates/29_adam.ipynb)
#
# # 🟠 Medium: Adam Optimizer
#
# **Adam** optimizer をスクラッチで実装する。
#
# ### Signature
# ```python
# class MyAdam:
#     def __init__(self, params, lr=1e-3, betas=(0.9, 0.999), eps=1e-8): ...
#     def step(self): ...
#     def zero_grad(self): ...
# ```
#
# ### Algorithm (param ごと)
# ```
# m = β1 * m + (1-β1) * grad
# v = β2 * v + (1-β2) * grad²
# m̂ = m / (1 - β1ᵗ)    # bias correction
# v̂ = v / (1 - β2ᵗ)
# p -= lr * m̂ / (√v̂ + ε)
# ```

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q --force-reinstall --no-deps git+https://github.com/alextfkd/TorchCode.git')
except ImportError:
    pass

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class MyAdam:
    def __init__(self, params, lr=1e-3, betas=(0.9, 0.999), eps=1e-8):
        pass  # params 保存、m と v を zeros で初期化

    def step(self):
        pass  # Adam rule で param update

    def zero_grad(self):
        pass  # 全 gradient を 0 化

# %%
# 🧪 Debug
torch.manual_seed(0)
w = torch.randn(4, 3, requires_grad=True)
opt = MyAdam([w], lr=0.01)
for i in range(5):
    loss = (w ** 2).sum()
    loss.backward()
    opt.step()
    opt.zero_grad()
    print(f'Step {i}: loss={loss.item():.4f}')

# %%
# ✅ SUBMIT
from torch_judge import check
check('adam')
