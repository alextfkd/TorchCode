# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/alextfkd/TorchCode/blob/master/templates/01_relu.ipynb)
#
# # 🟢 Easy: ReLU の実装
#
# **ReLU** (Rectified Linear Unit) activation 関数をスクラッチで実装する。
#
# $$\text{ReLU}(x) = \max(0, x)$$
#
#
# > 💡 **どこで使う**：CNN / MLP の隠れ層 activation のデフォルト。負値を切るだけなので軽く、勾配消失も緩和される。
#
# <details>
# <summary>📖 もっと詳しく</summary>
#
# AlexNet (2012) 以降 sigmoid / tanh を駆逐した定番。
#
# 弱点：`x ≤ 0` で勾配が完全に消える ("dying ReLU")。改良版に Leaky ReLU、PReLU、GELU (#19、Transformer で標準) など。
#
# </details>
#
# ### Signature
# ```python
# def relu(x: torch.Tensor) -> torch.Tensor:
#     ...
# ```
#
# ### Rules
# - `torch.relu`, `F.relu`, `torch.clamp` などの built-in activation は **使わない**
# - autograd をサポートすること（勾配が流れる）
#
# ### Example
# ```
# Input:  tensor([-2., -1., 0., 1., 2.])
# Output: tensor([ 0.,  0., 0., 1., 2.])
# ```

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q --force-reinstall --no-deps git+https://github.com/alextfkd/TorchCode.git')
except ImportError:
    pass

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def relu(x: torch.Tensor) -> torch.Tensor:
    pass  # 実装する

# %%
# 🧪 Test your implementation (feel free to add more debug prints)
x = torch.tensor([-2., -1., 0., 1., 2.])
print("Input: ", x)
print("Output:", relu(x))
print("Shape: ", relu(x).shape)

# %%
# ✅ SUBMIT — Run this cell to check your solution
from torch_judge import check
check("relu")

# %% [markdown]
# ---
#
# **詰まったら？** 解答を見る：
#
# [![Open Solution in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/alextfkd/TorchCode/blob/master/solutions/01_relu_solution.ipynb) または [GitHub で開く](https://github.com/alextfkd/TorchCode/blob/master/solutions/01_relu_solution.ipynb)
